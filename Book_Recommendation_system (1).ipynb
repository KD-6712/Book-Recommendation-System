# %%
import numpy as np
import pandas as pd

# %%
books = pd.read_csv('/content/Books.csv')
ratings = pd.read_csv('/content/Ratings.csv')
users = pd.read_csv('/content/Users.csv')

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author  Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                 2002     Oxford University Press
# 1  Richard Bruce Wright                 2001       HarperFlamingo Canada
# 2          Carlo D'Este                 1991             HarperPerennial
# 3      Gina Bari Kolata                 1999        Farrar Straus Giroux
# 4       E. J. W. Barber                 1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books['Image-URL-M'][1]
# Out:
# 'http://images.amazon.com/images/P/0002005018.01.MZZZZZZZ.jpg'

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (136772, 8)
# (1149780, 3)
# (278858, 3)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            1
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
books.describe()
# Out:
#        Year-Of-Publication
# count        136772.000000
# mean           1958.935491
# std             263.468996
# min               0.000000
# 25%            1990.000000
# 50%            1996.000000
# 75%            2000.000000
# max            2050.000000

# %%
users.describe()
# Out:
#             User-ID            Age
# count  278858.00000  168096.000000
# mean   139429.50000      34.751434
# std     80499.51502      14.428097
# min         1.00000       0.000000
# 25%     69715.25000      24.000000
# 50%    139429.50000      32.000000
# 75%    209143.75000      44.000000
# max    278858.00000     244.000000

# %%
ratings.describe()
# Out:
#             User-ID   Book-Rating
# count  1.149780e+06  1.149780e+06
# mean   1.403864e+05  2.866950e+00
# std    8.056228e+04  3.854184e+00
# min    2.000000e+00  0.000000e+00
# 25%    7.034500e+04  0.000000e+00
# 50%    1.410100e+05  0.000000e+00
# 75%    2.110280e+05  7.000000e+00
# max    2.788540e+05  1.000000e+01

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136772 entries, 0 to 136771
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 136772 non-null  object
#  1   Book-Title           136772 non-null  object
#  2   Book-Author          136772 non-null  object
#  3   Year-Of-Publication  136772 non-null  int64
#  4   Publisher            136770 non-null  object
#  5   Image-URL-S          136772 non-null  object
#  6   Image-URL-M          136772 non-null  object
#  7   Image-URL-L          136771 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 8.3+ MB

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %% [markdown]
# Popularity Based Recommendation

# %%
ratings_with_name = ratings.merge(books,on='ISBN')

# %%
num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_rating_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                    Apple Magic (The Collector's series)            1
# 2        Beyond IBM: Leadership Marketing and Finance ...            1
# 3                                            Dark Justice            1
# 4        Earth Prayers From around the World: 365 Pray...           10
# ...                                                   ...          ...
# 123603  Ã?Â?berallnie. AusgewÃ?Â¤hlte Gedichte 1928 - ...            1
# 123604                                     Ã?Â?bermorgen.            1
# 123605                     Ã?Â?rger mit Produkt X. Roman.            4
# 123606                              Ã?Â?stlich der Berge.            3
# 123607                                  Ã?Â?thique en toc            2
#
# [123608 rows x 2 columns]

# %%
avg_rating_df = ratings_with_name.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg_rating'},inplace=True)
avg_rating_df
# Out:
#                                                Book-Title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                    Apple Magic (The Collector's series)    0.000000
# 2        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# 3                                            Dark Justice   10.000000
# 4        Earth Prayers From around the World: 365 Pray...    5.000000
# ...                                                   ...         ...
# 123603  Ã?Â?berallnie. AusgewÃ?Â¤hlte Gedichte 1928 - ...   10.000000
# 123604                                     Ã?Â?bermorgen.    0.000000
# 123605                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 123606                              Ã?Â?stlich der Berge.    2.666667
# 123607                                  Ã?Â?thique en toc    4.000000
#
# [123608 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                    Apple Magic (The Collector's series)            1
# 2        Beyond IBM: Leadership Marketing and Finance ...            1
# 3                                            Dark Justice            1
# 4        Earth Prayers From around the World: 365 Pray...           10
# ...                                                   ...          ...
# 123603  Ã?Â?berallnie. AusgewÃ?Â¤hlte Gedichte 1928 - ...            1
# 123604                                     Ã?Â?bermorgen.            1
# 123605                     Ã?Â?rger mit Produkt X. Roman.            4
# 123606                              Ã?Â?stlich der Berge.            3
# 123607                                  Ã?Â?thique en toc            2
#
#         avg_rating
# 0         2.250000
# 1         0.000000
# 2         0.000000
# 3        10.000000
# ...

# %%
popular_df[popular_df['num_ratings']>=100]
# Out:
#                                                Book-Title  num_ratings  \
# 368                                                  1984          283
# 398                                   1st to Die: A Novel          509
# 486                                              24 Hours          104
# 511                                            2nd Chance          355
# 609                                             4 Blondes          151
# ...                                                   ...          ...
# 122615                                    Year of Wonders          169
# 122794                                   You Belong To Me          123
# 123276  Zen and the Art of Motorcycle Maintenance: An ...          210
# 123412                                               Zoya          103
# 123509                                \O\" Is for Outlaw"          269
#
#         avg_rating
# 368       4.469965
# 398       3.575639
# 486       2.394231
# 511       3.261972
# ...

# %%
popular_df[popular_df['num_ratings']>=100].sort_values('avg_rating',ascending=False).head(50)
# Out:
#                                                Book-Title  num_ratings  \
# 41118   Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 41110        Harry Potter and the Goblet of Fire (Book 4)          387
# 100350                                  The Little Prince          141
# 41123      Harry Potter and the Sorcerer's Stone (Book 1)          274
# 41113   Harry Potter and the Order of the Phoenix (Boo...          346
# 31150       Ender's Game (Ender Wiggins Saga (Paperback))          249
# 103673                    The Perks of Being a Wallflower          103
# 41103    Harry Potter and the Chamber of Secrets (Book 2)          556
# 98062   The Hobbit : The Enchanting Prelude to The Lor...          281
# 95744   The Fellowship of the Ring (The Lord of the Ri...          361
# 96797                  The Giver (21st Century Reference)          179
# 48145        Ishmael: An Adventure of the Mind and Spirit          162
# ...

# %%
popular_df = popular_df[popular_df['num_ratings']>=100].sort_values('avg_rating',ascending=False).head(50)

# %%
popular_df = popular_df.merge(books,on='Book-Title')
popular_df
# Out:
#                                             Book-Title  num_ratings  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 1    Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 2    Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 3         Harry Potter and the Goblet of Fire (Book 4)          387
# 4         Harry Potter and the Goblet of Fire (Book 4)          387
# ..                                                 ...          ...
# 150                                             Carrie          128
# 151  Tuesdays with Morrie: An Old Man, a Young Man,...          492
# 152  Tuesdays with Morrie: An Old Man, a Young Man,...          492
# 153                               The Valley of Horses          132
# 154                               The Valley of Horses          132
#
#      avg_rating        ISBN    Book-Author  Year-Of-Publication  \
# 0      5.852804  0439136350  J. K. Rowling                 1999
# ...

# %%
popular_df.drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','num_ratings','avg_rating']]
# Out:
#                                             Book-Title  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)
# 3         Harry Potter and the Goblet of Fire (Book 4)
# 5                                    The Little Prince
# 10      Harry Potter and the Sorcerer's Stone (Book 1)
# 13   Harry Potter and the Order of the Phoenix (Boo...
# 16       Ender's Game (Ender Wiggins Saga (Paperback))
# 20                     The Perks of Being a Wallflower
# 21    Harry Potter and the Chamber of Secrets (Book 2)
# 24   The Hobbit : The Enchanting Prelude to The Lor...
# 25   The Fellowship of the Ring (The Lord of the Ri...
# 31                  The Giver (21st Century Reference)
# 33        Ishmael: An Adventure of the Mind and Spirit
# 34                             Interpreter of Maladies
# 37   Harry Potter and the Sorcerer's Stone (Harry P...
# 39               Anne Frank: The Diary of a Young Girl
# 42                    Charlotte's Web (Trophy Newbery)
# ...

# %%
ratings_with_name.groupby('User-ID').count()['Book-Rating']>150
# Out:
# User-ID
# 2         False
# 8         False
# 9         False
# 10        False
# 12        False
#           ...
# 278846    False
# 278849    False
# 278851    False
# 278852    False
# 278854    False
# Name: Book-Rating, Length: 84007, dtype: bool

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating']>200
x[x]
# Out:
# User-ID
# 254       True
# 2276      True
# 2766      True
# 2977      True
# 3363      True
#           ...
# 274301    True
# 274308    True
# 275970    True
# 277427    True
# 278418    True
# Name: Book-Rating, Length: 641, dtype: bool

# %%
padhe_likhe_users = x[x].index

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(padhe_likhe_users)]

# %%
filtered_rating.groupby('Book-Title').count()['Book-Rating']>=25
# Out:
# Book-Title
#  A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)    False
#  Apple Magic (The Collector's series)                                                                         False
#  Beyond IBM: Leadership Marketing and Finance for the 1990s                                                   False
#  Dark Justice                                                                                                 False
#  Earth Prayers From around the World: 365 Prayers, Poems, and Invocations for Honoring the Earth              False
#                                                                                                               ...
# Â¿QuÃ© me quieres, amor?                                                                                      False
# Ã?ber den Wunsch, sich wohlzufÃ¼hlen: Geschichten                                                             False
# ...

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=25
famous_books = y[y].index
y[y]
# Out:
# Book-Title
# 10 Lb. Penalty                                                       True
# 16 Lighthouse Road                                                   True
# 1984                                                                 True
# 1st to Die: A Novel                                                  True
# 2010: Odyssey Two                                                    True
#                                                                      ...
# You Belong To Me                                                     True
# Zen and the Art of Motorcycle Maintenance: An Inquiry into Values    True
# Zlata's Diary: A Child's Life in Sarajevo                            True
# Zoya                                                                 True
# \O\" Is for Outlaw"                                                  True
# Name: Book-Rating, Length: 1940, dtype: bool

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]
final_ratings
# Out:
#         User-ID        ISBN  Book-Rating                       Book-Title  \
# 61       278418  0446520802            0                     The Notebook
# 63         3363  0446520802            0                     The Notebook
# 64         7158  0446520802           10                     The Notebook
# 67        11676  0446520802           10                     The Notebook
# 72        23768  0446520802            6                     The Notebook
# ...         ...         ...          ...                              ...
# 838727   274004  037572799X            0  In Pursuit of the Proper Sinner
# 838895   274061  0451176227            0                            Brain
# 838918   274061  1551663147           10                            Fever
# 839773   275970  0865714215            0                   Stormy Weather
# 839814   275970  1586210661            9           Me Talk Pretty One Day
#
#              Book-Author  Year-Of-Publication  \
# ...

# %%
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')
pt.fillna(0,inplace=True)
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# ...                                                    ...     ...     ...
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zlata's Diary: A Child's Life in Sarajevo              0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores
# Out:
# array([[1.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.0620173 ],
#        [0.        , 1.        , 0.        , ..., 0.        , 0.        ,
#         0.09406486],
#        [0.        , 0.        , 1.        , ..., 0.        , 0.08450515,
#         0.0521102 ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.08450515, ..., 0.        , 1.        ,
#         0.11219793],
#        [0.0620173 , 0.09406486, 0.0521102 , ..., 0.        , 0.11219793,
#         1.        ]])

# %%
similarity_scores.shape
# Out:
# (1940, 1940)

# %%
def recommend(book_name):
    # index fetch
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5]
    
    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)
    
    return data

# %%
recommend('Animal Farm')
# Out:
# [['Poland',
#   'James A. Michener',
#   'http://images.amazon.com/images/P/0394533887.01.MZZZZZZZ.jpg'],
#  ['Women in His Life',
#   'Barbara Taylor Bradford',
#   'http://images.amazon.com/images/P/0345345738.01.MZZZZZZZ.jpg'],
#  ['1984',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451524934.01.MZZZZZZZ.jpg'],
#  ['Midnight',
#   'Dean R. Koontz',
#   'http://images.amazon.com/images/P/0425118703.01.MZZZZZZZ.jpg']]
